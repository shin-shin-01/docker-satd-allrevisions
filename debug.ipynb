# %%
import pandas as pd
import os

# %%
os.listdir("./")
# Out:
# ['debug.ipynb',
#  '6-error-addInfo.txt',
#  '2-list-to-gitshow',
#  '7-satdCommnetsUNIQUE',
#  '9-checkSATDdeleted.py',
#  'a-getUniqueSATD.py',
#  '0-analysisFunc.py',
#  '8-allprojectCSV',
#  '.DS_Store',
#  '4-rowComments',
#  '2-gitlogsCSV',
#  '3-error-filenotExists.txt',
#  '5-satdComments',
#  '6-addDateRenameInfo.py',
#  'gitref_250images.txt',
#  '4-getComments.py',
#  '2-git_log_extractDockerfile.py',
#  '3-pastfiles',
#  '__pycache__',
#  'setting.py',
#  '1-repositories',
#  'README.md',
#  'delete.sh',
#  '1-git_clone.py',
#  '.gitignore',
#  'fix_bug.py',
#  'a-extractComment',
#  '2-error-gitlogs.txt',
#  '.ipynb_checkpoints',
#  '9-allprojectCSV',
#  '2-gitlogsTXT',
#  '1-error-gitclone.txt',
#  '.git',
#  '6-satdCommentsAddInfo',
#  '8-creatAllProjectCSV.py',
#  'data',
#  '3-getPastFile.py',
#  'satd-keywords.txt',
#  'rq',
#  '5-detecctSATD.py',
#  '7-fixSameSATD.py']

# %%
df = pd.read_csv('./6-satdCommentsAddInfo/docker_docker-ce.csv', index_col=0)
df
# Out:
#                                       CommitID  \
# 0     1eb155ca7f0e14cfbb5f59b0cdcabd733033f5d8
# 1     1eb155ca7f0e14cfbb5f59b0cdcabd733033f5d8
# 2     1eb155ca7f0e14cfbb5f59b0cdcabd733033f5d8
# 3     1eb155ca7f0e14cfbb5f59b0cdcabd733033f5d8
# 4     169ed37aca37a12c1dc5d73a3955cade97b9af83
# ...                                        ...
# 2916  da1e08d48493406ce290a1b99269e52879af5b0e
# 2917  da1e08d48493406ce290a1b99269e52879af5b0e
# 2918  da1e08d48493406ce290a1b99269e52879af5b0e
# 2919  da1e08d48493406ce290a1b99269e52879af5b0e
# 2920  da1e08d48493406ce290a1b99269e52879af5b0e
#
#                                                Author  \
# 0     Tibor Vass <tiborvass@users.noreply.github.com>
# 1     Tibor Vass <tiborvass@users.noreply.github.com>
# 2     Tibor Vass <tiborvass@users.noreply.github.com>
# 3     Tibor Vass <tiborvass@users.noreply.github.com>
# 4      unclejack <unclejack@users.noreply.github.com>
# ...                                               ...
# ...

# %%
df["RenameList"] = df["RenameList"]apply(lambda renames: renames.split())
# Out:
#   File "<ipython-input-6-6ad9003abc60>", line 1
#     df["RenameList"] = df["RenameList"]apply(lambda renames: renames.split())
#                                        ^
# SyntaxError: invalid syntax
